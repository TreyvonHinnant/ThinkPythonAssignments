# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Week_5_Chapter_5_Conditionals_and_Recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
# 3. Logic: If hour < 17, subtract 2 from the price.
# 4. Print the final price.
