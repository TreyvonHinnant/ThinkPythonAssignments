# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Midterm_Project%3A%20Rental_Car_Pricing_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name: rentalcar.py

# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
def get_full_name(code):
  # """Returns full name of classification code."""

def calculate_mileage_cost

  # """Calculates mileage cost: First 100 miles free, then $0.35/mile."""

# """Fruthful function to calculate total bill. No prints."""

# PROGRAM LOGIC

# Input Validation for Code

# Get Days and Mileage

# Calculate Miles

# Calculate Final Bill

# Final Output

# Run the program
