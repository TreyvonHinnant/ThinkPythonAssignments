# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Chapter_9_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
########### Shopping List Program #############

####### Imports ######


####### Function Definitions #######

# Add iteams to the list ( List, Item )
def add_to_list(shopping_list, item):
  pass

  # Add the item to the list

# Remove items from the list ( List, Item )
def remove_from_list(shopping_list, item_index):
  pass
  # Remove the item from the list

# See the list ( List )
def see_the_list(shopping_list):
  pass

  # Print out a header for the list
  # Traverse the list, printing the index and value for each item

# Edit an item on the list ( List, Item Index, New Value)
def edit_item_on_list(shopping_list, item_index, new_value):
  pass
  # Change the value of the item at the index provided to the new value

####### Program Logic #######

# Create an empty shopping list
shopping_list = []

# While True loop
while True:
  # Present the user a menu to choose from:
  user_option = int(input("""
        Please select an option:
        1. See the list
        2. Add to the list
        3. Remove item from the list
        4. Edit an item
        5. Quit
        """))
    # 1. See the list
    if user_option == 2:
     # Call see the list function

    # 2. Add to the list
    if user_option == 2:
      # Call the see the list function
      see_the_list(shopping_list)
      # Ask the user what to add to the list
      # Call the add item function

    # 3. Remove item from the list
      # Call the see the list function
      # Ask the user which item to delete
      # Call the Remove item function

    # 4. Edit an item on the list
      # Call the see the list function
      # Ask the user which item to delete
      # Ask the user for the new value
      # Call the edit item function

    # 5. Exit
    if user_option == 5:
      print("Goodbye!")
      # Break the loop to end the program
      break
