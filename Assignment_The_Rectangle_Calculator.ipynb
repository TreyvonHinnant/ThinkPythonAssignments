# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Assignment_The_Rectangle_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name: recentagle.py

# Import Statements

# Function Definitions

# Define the function with 'length' and 'width' as paramenters

# Calculate the 'area' by length and width

# Calculate the 'perimeter' twice the length and width

# Create a tuple containing 'area' and 'perimeter'

# Return the tuple


# Program Logic

# Ask the user for length and width inputs and convert them into floats

# Call the calculate_rectangle function

# Use two seperate variables (my_area, my_perimeter)

# Print the final results
