# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Week_8_The_Palindrome_Tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FUNCTION is_palindrome(input_string):
  # Normalize the string: remove spaces/punctuation and convert to lowercase
  # (Optional, but recommended for robust palindrome checking of phases)
  cleaned_string = remove_non_alphanumeric(input_string)
  cleaned_string = convert_to_lowercase(cleaned_string)

# Initialize two pointers: 'left' at the start and 'right' at the end
left = 0
right = LENGTH(cleaned_string) - 1

# Logic while the left pointer is less than the right pointer
WHILE left < right
  # Compare the characters at the 'left' and 'right' positions
  IF cleaned_string[left] is not eqaul to cleaned_string
    # If they don't match, it's not a palindrome, return False immediately
    RETURN False
# Move the pointers inward
left = left + 1
right = right - 1

# If the loop completes without finding any mismatches, it's a palindrome
RETURN True
