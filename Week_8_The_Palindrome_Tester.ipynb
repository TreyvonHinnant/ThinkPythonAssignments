# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Week_8_The_Palindrome_Tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#=========================================
# HEADER: Palindrome Tester Program
#=========================================

# 1. Get Input
#    - Use input() to ask the user for a string.
#    - Store input in a variable (e.g., original_str).

# 2. Clean Input
#    - Remove non-alphanumeric characters (punctuation, spaces) using .isalnum()
#    - Convert the entire string to lowercase using .lower().
#    - Store clean version (e.g., clean_str).

# 3. Reverse String
#    - Reverse the clean_str using slicing [::-1] or reversed().
#    - Store reversed version (e.g., reversed_str).

# 4. Compare and Output
#    - If clean_str equals reversed_str:
#        - Print "It is a palindrome."
#    - Else:
#        - Print "It is not a palindrome."
