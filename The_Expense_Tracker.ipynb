# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/The_Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Expense Tracker.py

# Goal: Manage a collection of expense data and generate reports.

# 1. Initialize an empty list called 'expenses' to hold dictionary objects.

# 2. Create a 'while' loop that runs until the user chooses to exit.

# 3. Inside the loop, displays a menu: 1) Add Expense, 2) Get Totals, 3) Exit.

# 4. If 'Add':
#     - Prompt for Category, Vendor, Amount, and Date.
#     - Store these in a dictionary: {'category': val, 'vendor': val, 'amount': val, 'date': val}.
#     - Append dictionary to 'expenses' list.

# 5. If 'Totals':
#     - Sub-menu: A) All, C) Category, V) Vendor.
#     - If Category/Vendor: Loop through 'expenses', check if key matches user input, sum 'amount'.

# 6. If 'Exit': Break loop
