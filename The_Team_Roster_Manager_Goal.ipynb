# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/The_Team_Roster_Manager_Goal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS

# ADD_PLAYERS
# def add_players:
#  """Allows user to input players until 'quit' is typed."""
# while True:
#    name = input("Enter player name (or 'quit' to stop): ")
print("Lebron James")
print('Quit')
# elif name.lower() == 'quit':

# IS_ON_ROSTER
# def is_on_roster(team_list, name_to_find):
print("LA Lakers")
#  """If a player is in the list and returns True/False."""
# elif name_to_find in team_list:
# return True
# else:
# return False

# PROGRAM LOGIC

# CREATE EMPTY ROSTER
# roster = []

# CALL ADD_PLAYERS
# add_players(roster)

# ASK THE USER A FOR NAME
# search user name (roster)
print("6")

# CALL IS_ON_ROSTER
# elif is_on_roster(roster, search name)
print("Results: Player found!")
# else:
print("Results: Player not found!")
# Out:
# Lebron James
# Quit
# LA Lakers
# 6
# Results: Player found!
# Results: Player not found!
