# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Rental_Car_Pricing_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name: [Your Name]

# Import Statements

# Car Classification:

# Mileage Logic:

# Modular Funtcions:

# Rental Car Pricing System (Budget, Standard, Luxury):

# Input Validation:

# Fruitful Function that calculates the total bill:

# Classification Code:

# Program Logic:
