# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/The_Digital_Library_Manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py

# IMPORT STATEMENTS

# CLASS DEFINIITIONS

# Define a class named Book

# Define _init_ to accept title and author

# Set self.title = title

# Set self.author = author

# Set self.is available to True by default

# Define_str_to return a string:

# Check if self.is_available is True: return "Available"

# Else: return "Checked Out"

# Define checkout method:

# Access this specific object's is_available attribute using self

# Set it to False

# PROGRAM LOGIC
