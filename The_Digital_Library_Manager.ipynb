# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/The_Digital_Library_Manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py

# IMPORT STATEMENTS

# CLASS DEFINIITION
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_available = True

    def __str__(self):
        status = "Available" if self.is_available else "Checked Out"
        return f"{self.title} by {self.author} - {status}"

    def checkout(self):
        self.is_available = False
        self.is_available = True

# PROGRAM LOGIC
# Create instances
book1 = Book("Think Python", "Allen Downey")
book2 = Book("The Cat In The Hat", "Dr.Suess")

# Intital Status
print("--- Library Status ---")
print(book1)
print(book2)

# Perform Action
print(f"\nChecking Out '{book2}'...")
book2.checkout()

# Updated Status
print("\n--- Updated Status ---")
print(book1)
print(book2)
# Out:
# --- Library Status ---
# Think Python by Allen Downey - Available
# The Cat In The Hat by Dr.Suess - Available
#
# Checking Out 'The Cat In The Hat by Dr.Suess - Available'...
#
# --- Updated Status ---
# Think Python by Allen Downey - Available
# The Cat In The Hat by Dr.Suess - Available
