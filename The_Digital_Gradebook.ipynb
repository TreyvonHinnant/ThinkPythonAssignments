# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/The_Digital_Gradebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: gradebook.py

# Import Statements

# Function Definitions

# Define add_students
def add_students(gradebook_dict):

# Dictionary as parameter

# Use a while loop to ask student names and grades

# Inputs "done" for the name

# Convert grade input

# Define calculate_average
def calculate_average(gradebook_dict):

# Accept the gradebook dictionary

# Check if the dictionary is empty

# If not empty, get all values (grades)

# Calculate the sum and count the grades

# Return the average (sum / count)

# Program Logic

# Initialize an empty dictionary called gradebook

# Call add_students to populate the dictionary

# Call calculate_average and display the resulting class average

# Print a final report showing each student's name and their grade
