# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Week2/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (NONE)

# FUNCTIONS DEFINITIONS
# (NONE)

# PROGRAM LOGIC
# 1. PRINT the total minutes in a movie (2 x 60 + 45)
# 2. Print the years since 1947 (2026 - 1947)
# 3. Print the total cost of 7 books (7 x 35)
