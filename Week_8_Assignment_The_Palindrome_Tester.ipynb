# %% [markdown]
# <a href="https://colab.research.google.com/github/TreyvonHinnant/ThinkPythonAssignments/blob/main/Week_8_Assignment_The_Palindrome_Tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
def is_palindrome(word):
    # 1. Convert input word to lowercase to handle case-insensitivity
    # 2. Reverse the lowercase word
    # 3. Compare the original lowercase word with reversed word
    # 4. Return True if they match, False otherwise
    pass

# PROGRAM LOGIC
# 1. Prompt user to input a word
# 2. Call the is_palindrome function with user input
# 3. Print if the word is a palindrome or not
